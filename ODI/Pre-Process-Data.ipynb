# %%
import pandas as pd
import numpy as np
import re
import datetime

# %% [markdown]
# # 1. Read Data

# %%
data = pd.read_csv('ODI-2019-csv.csv', sep=';')

# %% [raw]
# import matplotlib.pyplot as plt
#
# plt.matshow(data.corr)
# plt.show()

# %% [markdown]
# # 2. Pre-Process Data

# %%
# Copy data dataframe to adapt
data_processed = data.copy()

# %% [markdown]
# ## 2.1 Normalize Programmes

# %%
data_processed[data_processed.columns[1]] = data_processed[data_processed.columns[1]].str.lower()
data_processed[data_processed.columns[1]] = data_processed[data_processed.columns[1]].str.strip()

# %%
replacement = {'artificial intelligence':['artificial intelligence master','ai','m ai','master ai','msc artificial intelligence','msc artificial intelligence: cognitive science','uva ai'],
               'bioinformatics and systems biology':['bioinf','bioinformatics','bioinformatics & systems biology','bioinformatics and biology systems','bioinformatics and systems biology master\'s','bioinformatics and system biology','bioinformatics and systems biology msc','boinformatics','biosb','m bioinformatics','master of bioinformatics and system biology','msc bioinformatic','msc bioinformatics & systems biology','msc bioinformatics'],
               'computational science':['cls','clsjd','computational science joint degree','masters compuational science','msc computational science'],
               'computer science':['computer science (joint degree)','computer science masters','cs','cs (exchange)','master computer science','computer science - internet and web technologies', 'computer science big data engineering master','mscs','msc computer science (big data engineering)'],
               'business administration/business analytics':['mba','ba','business analytics and data science','business analytics','business administration','digital business & innovation','dbi digital business and innovation','master digital business and innovation', 'business administration: digital business & innovation','business adminitration','digital business and innovation'],
               'information sciences':['information studies: data science (uva)','ma data science (uva)','information studies','ds','uva: information systems - data science','uva msc information studies: data science','uva master information studies, track data science'],
               'finance':['quantitative risk management','qrm','msc qrm (dhp)','master of finance','dhpqrm','duisenberg qrm'],
               'humanities research':['rm humanities: linguistics','ma language technology'],
               'econometrics and operations research':['operation research','eor','econometrics and operations research','econometrics','financial econometrics','financial econometrivs','master econometrics','master econometrics & or','masters eor'],
               'health sciences':['master health sciences'],
               'management, policy analysis and entrepeneurship in health and life sciences':['master management, policy analysis and entrepeneurship in health and life sciences'],
               'other':['ms','x','multiple programmes'],
               'sociology':['exchange student (sociology)'],
               'stochastics and financial mathematics':['maths, stochastics, master, uva']}

# %%
for key in replacement:
    data_processed[data_processed.columns[1]]=data_processed[data_processed.columns[1]].replace(to_replace = replacement[key], value = key)

# %% [raw]
# data_programme = data_processed.groupby(data.columns[1])

# %% [raw]
# data_programme.groups

# %% [markdown]
# ## 2.2 Normalize Birthdates

# %%
data_processed[data_processed.columns[8]] = data_processed[data_processed.columns[8]].str.lower()
data_processed[data_processed.columns[8]] = data_processed[data_processed.columns[8]].str.strip()

# %% [raw]
# row = data_processed[data_processed.columns[8]][12]
# if any(month in row for month in months):
#     print(row)

# %% [raw]
# date = data_processed[data_processed.columns[8]][12]
# month, x = monthfinder(date)
# print(month)

# %% [raw]
# import string
# print(string.punctuation)
# date = data_processed[data_processed.columns[8]][2]
# re.sub(r"["+string.punctuation+"]+", ' ', date)

# %%
months = [(lambda x:datetime.date(1900, x, 1).strftime('%B'))(x) for x in range(13)[1:]]+([(lambda x:datetime.date(1900, x, 1).strftime('%b'))(x) for x in range(13)[1:]])
months = [x.lower() for x in months]

def monthfinder(date):
    for month in months:
        x = date.find(month)
        if x != -1:
            return month, x
    return None, None

# %%
def numericalsplit(date):
    #only day or month or year
    if len(date) <= 2:
        
        #only year
        if int(date) > 31:
            date = "//19" + date
            
        #assuming only month
        elif int(date) < 13:
            date = "/" + date + "/"
                
        #only day, contains no information
        else:
            date = "//" 
        
    #only day/month, month/year or year
    elif len(date) == 4:
        
        #only year
        if (int(date[:2]) == 19) & (int(date[2:4])>12):    
            date = "//" + date
        
        else:
            #assuming year/month
            if int(date[:2]) > 31:
                date = "/" + date[2:] + "/" + "19" + date[:2]
            
            #assuming month/year
            elif int(date[2:]) > 31:
                date = "/" + date[:2] + "/" + "19" + date[2:]
            
            #assuming month/day
            elif int(date[2:]) > 12:
                date = date[2:] + "/" + date[:2] + "/"
            
            #assuming day/month
            else:
                date = date[:2] + "/" + date[2:] + "/"
    
    #only day/month/year or month/year
    elif len(date) == 6:
        
        #assuming year/month
        if int(date[:2]) == 19 & (int(date[2:4])>12):
            date = "/" + date[4:] + "/" + date[:4]
        
        #assuming month/year
        elif int(date[2:4]) == 19 & (int(date[4:])>12):
            date = "/" + date[:2] + "/" + date[2:]
        
        #assuming month/day/year
        elif int(date[2:4]) > 12:
            date = date[2:4] + "/" + date[:2] + "/19" + date[4:]
        
        #assuming day/month/year
        else:
            date = date[:2] + "/" + date[2:4] + "/19" + date[4:]
    
    #day/month/year
    elif len(date) == 8:
        
        if (int(date[:2]) == 19) & (int(date[2:4])>12):
            
            #assuming year/month/day
            if int(date[6:]) > 12:
                date = date[6:] + "/" + date[4:6] + "/" + date[:4]
            
            #assuming year/day/month
            else:
                date = date[4:6] + "/" + date[6:] + "/" + date[:4]

        else:
            
            #assuming month/day/year
            if int(date[2:4]) > 12:
                date = date[2:4] + "/" + date[:2] + "/" + date[4:]
            
            #assuming day/month/year
            else:
                date = date[:2] + "/" + date[2:4] + "/" + date[4:]
    
    return date

# %%
def fixdate(date):
    datelist = date.split('/')
    
    datelist = list(filter(None, datelist))
    if len(datelist) == 0:
        date = "//"
        
    elif len(datelist) == 1:
        date = numericalsplit(datelist[0])

    elif len(datelist) == 2:
        
        # year/month
        if int(datelist[0]) > 31:

            # check if full year
            if len(datelist[0]) == 2:
                datelist[0] = "19" + datelist[0]
            
            date = "/".join(["",datelist[1],datelist[0]])
        
        # month/year
        elif int(datelist[1]) > 31:
            
            # check if full year
            if len(datelist[1]) == 2:
                datelist[1] = "19" + datelist[1]
                
            date = "/".join(["",datelist[0],datelist[1]])
            
        # month/day
        elif int(datelist[1]) > 12:
            date = "/".join([datelist[1],datelist[0],""])
        
        # day/month
        else:
            date = "/".join([datelist[0],datelist[1],""])
    
    else:

        if int(datelist[0]) > 31:

            # check if full year
            if len(datelist[0]) == 2:
                datelist[0] = "19" + datelist[0]

            # year/month/day
            if int(datelist[2]) > 12:
                date = "/".join([datelist[2],datelist[1],datelist[0]])
                
            # year/day/month
            else:
                date = "/".join([datelist[1],datelist[2],datelist[0]])

        # assuming never */year/*

        else:

            # check if full year
            if len(datelist[2]) == 2:
                datelist[2] = "19" + datelist[2]

            # month/day/year
            if int(datelist[1]) > 12:
                date = "/".join([datelist[1],datelist[0],datelist[2]])
            
            # day/month/year
            else:
                date = "/".join([datelist[0],datelist[1],datelist[2]])

    return date

# %%
def removesep(date, sep):
    datelist = []
    for x in date:
        if x == sep:
            pass
        else:
            datelist.append(x)
    date = "".join(datelist)
    return date

# %%
def replacesep(date):
    datelist = []
    for x in date:
        if not (x.isalpha() or x.isdigit()):
            datelist.append("/")
        else:
            datelist.append(x)
    date = "".join(datelist)
    date = re.sub('/+', '/', date)
    date = fixdate(date)
    return date

# %%
def replacemonth(date):
    month, x = monthfinder(date)
    while month != None:
        index = months.index(month)%12+1
        date = date.replace(month," " + str(index) + " ")
        month, x = monthfinder(date)
    if month == None:
        pass
    date = re.sub(' +', ' ', date)
    date = date.strip()
    return date

# %%
def removealpha(date):
    datelist = []
    for x in date:
        if x.isalpha():
            pass
        else:
            datelist.append(x)
    date = "".join(datelist)
    date = re.sub(' +', ' ', date)
    return date

# %%
dates = []
for date in data_processed[data_processed.columns[8]]:    
    date = removesep(date, "\'")
    
    if bool(re.match('^(?=.*/.*)',date)):
        date = replacesep(date)
    
    if removesep(date," ").isalpha():
        month, x = monthfinder(date)
        if month == None:                                    #contains no information
            date = "//"
        else:
            date = replacemonth(date)
            date = removealpha(date).strip()
            if date.isdigit():
                date = numericalsplit(date)
        
    else:
        date = replacemonth(date)
        date = removealpha(date)
        if date.isdigit():
            date = numericalsplit(date)
        else:
            date = replacesep(date)
    date = date.split('/')
    dates.append(date)

# %%
cols=['Birth Day','Birth Month','Birth Year']
data = pd.DataFrame(dates,columns=cols)
data = data.replace(r'', np.nan, regex=True)
data = data.astype('float64')
data.style.format({
    'A': '{:,f}'.format,
    'B': '{:,f}'.format,
})
#data.head(5)
# Out:
# <style  type="text/css" >
# </style><table id="T_f794962e_591f_11e9_84d6_54e1ad192a88" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Birth Day</th>        <th class="col_heading level0 col1" >Birth Month</th>        <th class="col_heading level0 col2" >Birth Year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row0_col0" class="data row0 col0" >nan</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row0_col2" class="data row0 col2" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row1_col0" class="data row1 col0" >9</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row1_col1" class="data row1 col1" >7</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row1_col2" class="data row1 col2" >1992</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row2_col0" class="data row2 col0" >4</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row2_col2" class="data row2 col2" >1995</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row3_col0" class="data row3 col0" >29</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row3_col1" class="data row3 col1" >9</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row3_col2" class="data row3 col2" >1993</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row4_col0" class="data row4 col0" >2</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row4_col1" class="data row4 col1" >12</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row4_col2" class="data row4 col2" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row5_col0" class="data row5 col0" >31</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row5_col1" class="data row5 col1" >12</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row5_col2" class="data row5 col2" >1994</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row6_col0" class="data row6 col0" >9</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row6_col1" class="data row6 col1" >10</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row6_col2" class="data row6 col2" >1995</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row7_col0" class="data row7 col0" >22</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row7_col1" class="data row7 col1" >7</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row7_col2" class="data row7 col2" >1996</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row8_col0" class="data row8 col0" >30</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row8_col1" class="data row8 col1" >2</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row8_col2" class="data row8 col2" >1945</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row9_col0" class="data row9 col0" >nan</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row9_col1" class="data row9 col1" >nan</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row9_col2" class="data row9 col2" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row10_col0" class="data row10 col0" >10</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row10_col1" class="data row10 col1" >6</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row10_col2" class="data row10 col2" >1991</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row11_col0" class="data row11 col0" >nan</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row11_col1" class="data row11 col1" >nan</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row11_col2" class="data row11 col2" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row12_col0" class="data row12 col0" >18</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row12_col1" class="data row12 col1" >3</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row12_col2" class="data row12 col2" >1994</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row13_col0" class="data row13 col0" >2</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row13_col1" class="data row13 col1" >8</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row13_col2" class="data row13 col2" >1996</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row14_col0" class="data row14 col0" >1</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row14_col1" class="data row14 col1" >5</td>
#                         <td id="T_f794962e_591f_11e9_84d6_54e1ad192a88row14_col2" class="data row14 col2" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_f794962e_591f_11e9_84d6_54e1ad192a88level0_row15" class="row_heading level0 row15" >

# %%
pd.concat([data_processed,data],axis=1)
# Out:
#               Timestamp                  What programme are you in?  \
# 0    3/27/2019 10:16:11                     artificial intelligence
# 1     4/1/2019 15:58:21                     artificial intelligence
# 2     4/1/2019 15:59:07                            computer science
# 3     4/1/2019 15:59:30        econometrics and operations research
# 4     4/1/2019 15:59:58                            computer science
# 5     4/1/2019 16:00:01                     artificial intelligence
# 6     4/1/2019 16:00:12          bioinformatics and systems biology
# 7     4/1/2019 16:00:16          bioinformatics and systems biology
# 8     4/1/2019 16:00:21                       computational science
# 9     4/1/2019 16:00:31                     artificial intelligence
# 10    4/1/2019 16:00:52          bioinformatics and systems biology
# 11    4/1/2019 16:00:59                       computational science
# 12    4/1/2019 16:00:59                     artificial intelligence
# 13    4/1/2019 16:01:02  business administration/business analytics
# 14    4/1/2019 16:01:03  business administration/business analytics
# 15    4/1/2019 16:01:04        econometrics and operations research
# 16    4/1/2019 16:01:04        econometrics and operations research
# 17    4/1/2019 16:01:06  business administration/business analytics
# 18    4/1/2019 16:01:09          bioinformatics and systems biology
# 19    4/1/2019 16:01:13  business administration/business analytics
# 20    4/1/2019 16:01:13          bioinformatics and systems biology
# 21    4/1/2019 16:01:13                     artificial intelligence
# 22    4/1/2019 16:01:13                     artificial intelligence
# 23    4/1/2019 16:01:14                     artificial intelligence
# 24    4/1/2019 16:01:15                     artificial intelligence
# 25    4/1/2019 16:01:16          bioinformatics and systems biology
# 26    4/1/2019 16:01:16                     artificial intelligence
# 27    4/1/2019 16:01:17                       computational science
# 28    4/1/2019 16:01:17          bioinformatics and systems biology
# 29    4/1/2019 16:01:17  business administration/business analytics
# ..                  ...                                         ...
# 246   4/1/2019 16:02:11        econometrics and operations research
# 247   4/1/2019 16:02:12                     artificial intelligence
# 248   4/1/2019 16:02:11                         humanities research
# 249   4/1/2019 16:02:12                       computational science
# 250   4/1/2019 16:02:13                            computer science
# 251   4/1/2019 16:02:14                     artificial intelligence
# 252   4/1/2019 16:02:14                            computer science
# 253   4/1/2019 16:02:15                       computational science
# 254   4/1/2019 16:02:15                            computer science
# 255   4/1/2019 16:02:16                            computer science
# 256   4/1/2019 16:02:16                       computational science
# 257   4/1/2019 16:02:16                            computer science
# 258   4/1/2019 16:02:18                     artificial intelligence
# 259   4/1/2019 16:02:20                       computational science
# 260   4/1/2019 16:02:21          bioinformatics and systems biology
# 261   4/1/2019 16:02:24                            computer science
# 262   4/1/2019 16:02:23                       computational science
# 263   4/1/2019 16:02:24                            computer science
# 264   4/1/2019 16:02:25  business administration/business analytics
# 265   4/1/2019 16:02:25                     artificial intelligence
# 266   4/1/2019 16:02:29                            computer science
# 267   4/1/2019 16:02:39  business administration/business analytics
# 268   4/1/2019 16:02:40                       computational science
# 269   4/1/2019 16:02:44                       computational science
# 270   4/1/2019 16:02:45  business administration/business analytics
# 271   4/1/2019 16:02:55  business administration/business analytics
# 272   4/1/2019 16:02:56                            computer science
# 273   4/1/2019 16:03:51                     artificial intelligence
# 274   4/1/2019 16:31:16                                  psychology
# 275   4/1/2019 16:53:39                     artificial intelligence
#
#     Have you taken a course on machine learning?  \
# 0                                            yes
# 1                                             no
# 2                                            yes
# 3                                            yes
# 4                                             no
# 5                                            yes
# 6                                            yes
# 7                                            yes
# 8                                             no
# 9                                            yes
# 10                                           yes
# 11                                            no
# 12                                           yes
# 13                                           yes
# 14                                           yes
# 15                                           yes
# 16                                            no
# 17                                           yes
# 18                                           yes
# 19                                           yes
# 20                                           yes
# 21                                            no
# 22                                            no
# 23                                           yes
# 24                                           yes
# 25                                           yes
# 26                                           yes
# 27                                            no
# 28                                           yes
# 29                                           yes
# ..                                           ...
# 246                                           no
# 247                                          yes
# 248                                           no
# 249                                      unknown
# 250                                           no
# 251                                          yes
# 252                                           no
# 253                                          yes
# 254                                           no
# 255                                           no
# 256                                          yes
# 257                                          yes
# 258                                          yes
# 259                                          yes
# 260                                          yes
# 261                                          yes
# 262                                           no
# 263                                          yes
# 264                                          yes
# 265                                          yes
# 266                                           no
# 267                                          yes
# 268                                           no
# 269                                           no
# 270                                          yes
# 271                                          yes
# 272                                           no
# 273                                           no
# 274                                           no
# 275                                          yes
#
#     Have you taken a course on information retrieval?  \
# 0                                                   1
# 1                                                   0
# 2                                                   1
# 3                                                   1
# 4                                                   1
# 5                                                   1
# 6                                                   0
# 7                                                   1
# 8                                                   0
# 9                                                   1
# 10                                                  0
# 11                                                  0
# 12                                                  1
# 13                                                  1
# 14                                                  1
# 15                                                  0
# 16                                                  0
# 17                                                  1
# 18                                                  1
# 19                                                  0
# 20                                                  0
# 21                                                  1
# 22                                                  0
# 23                                                  1
# 24                                                  1
# 25                                                  0
# 26                                                  0
# 27                                                  0
# 28                                                  1
# 29                                                  0
# ..                                                ...
# 246                                                 0
# 247                                                 0
# 248                                                 0
# 249                                                 0
# 250                                                 1
# 251                                                 1
# 252                                                 1
# 253                                                 1
# 254                                                 1
# 255                                                 1
# 256                                                 0
# 257                                                 1
# 258                                                 0
# 259                                                 1
# 260                                                 1
# 261                                                 1
# 262                                                 0
# 263                                                 1
# 264                                                 1
# 265                                                 1
# 266                                                 0
# 267                                                 0
# 268                                                 0
# 269                                                 0
# 270                                                 1
# 271                                                 0
# 272                                                 0
# 273                                                 1
# 274                                           unknown
# 275                                                 1
#
#     Have you taken a course on statistics?  \
# 0                                       mu
# 1                                       mu
# 2                                  unknown
# 3                                       mu
# 4                                       mu
# 5                                       mu
# 6                                       mu
# 7                                       mu
# 8                                       mu
# 9                                       mu
# 10                                      mu
# 11                                      mu
# 12                                      mu
# 13                                      mu
# 14                                      mu
# 15                                      mu
# 16                                      mu
# 17                                      mu
# 18                                      mu
# 19                                      mu
# 20                                      mu
# 21                                      mu
# 22                                      mu
# 23                                      mu
# 24                                      mu
# 25                                      mu
# 26                                      mu
# 27                                      mu
# 28                                      mu
# 29                                      mu
# ..                                     ...
# 246                                     mu
# 247                                     mu
# 248                                  sigma
# 249                                  sigma
# 250                                     mu
# 251                                  sigma
# 252                                unknown
# 253                                     mu
# 254                                     mu
# 255                                     mu
# 256                                     mu
# 257                                     mu
# 258                                     mu
# 259                                     mu
# 260                                     mu
# 261                                     mu
# 262                                     mu
# 263                                     mu
# 264                                     mu
# 265                                  sigma
# 266                                  sigma
# 267                                     mu
# 268                                     mu
# 269                                     mu
# 270                                     mu
# 271                                     mu
# 272                                     mu
# 273                                  sigma
# 274                                  sigma
# 275                                     mu
#
#     Have you taken a course on databases? What is your gender?  \
# 0                                      ja              unknown
# 1                                      ja                 male
# 2                                      ja                 male
# 3                                      ja                 male
# 4                                      ja                 male
# 5                                      ja                 male
# 6                                     nee               female
# 7                                      ja                 male
# 8                                      ja                 male
# 9                                     nee                 male
# 10                                    nee                 male
# 11                                    nee                 male
# 12                                    nee                 male
# 13                                     ja                 male
# 14                                     ja                 male
# 15                                    nee                 male
# 16                                    nee                 male
# 17                                     ja                 male
# 18                                     ja                 male
# 19                                     ja               female
# 20                                     ja               female
# 21                                    nee               female
# 22                                     ja                 male
# 23                                     ja               female
# 24                                     ja                 male
# 25                                    nee                 male
# 26                                     ja               female
# 27                                    nee               female
# 28                                     ja               female
# 29                                    nee                 male
# ..                                    ...                  ...
# 246                                   nee                 male
# 247                                   nee                 male
# 248                                   nee               female
# 249                                    ja                 male
# 250                                   nee                 male
# 251                                   nee                 male
# 252                                    ja               female
# 253                                    ja                 male
# 254                                    ja                 male
# 255                                    ja                 male
# 256                                   nee                 male
# 257                                    ja               female
# 258                                   nee                 male
# 259                                   nee              unknown
# 260                                    ja                 male
# 261                                    ja               female
# 262                                   nee                 male
# 263                                    ja                 male
# 264                                   nee                 male
# 265                                    ja                 male
# 266                                    ja                 male
# 267                                   nee                 male
# 268                                   nee                 male
# 269                                   nee               female
# 270                                    ja                 male
# 271                                    ja                 male
# 272                                    ja                 male
# 273                                    ja                 male
# 274                                   nee              unknown
# 275                                    ja               female
#
#                       Chocolate makes you..... When is your birthday (date)?  \
# 0                                         slim                       unknown
# 1                                          fat                      09071992
# 2                                      neither                      04/08/95
# 3                                          fat                    29-09-1993
# 4                                      neither                          0212
# 5                                      unknown                    31-12-1994
# 6                                      neither                    09-10-1995
# 7    I have no idea what you are talking about                    22/07/1996
# 8                                      neither                    30-02-1945
# 9                                      neither                            22
# 10                                     neither                    10/06/1991
# 11                                         fat                            19
# 12   I have no idea what you are talking about                 18 march 1994
# 13                                         fat                    02-08-1996
# 14                                         fat                         1 may
# 15                                     neither                          1996
# 16                                         fat                    03-03-1994
# 17                                         fat                    17-05-1994
# 18                                         fat                         08-28
# 19                                     neither                    27/12/1996
# 20                                         fat                    18-10-1996
# 21                                        slim                    21-08-1995
# 22                                         fat                     10th,june
# 23                                         fat                    09/08/1996
# 24                                     neither                    24-02-1994
# 25                                     neither                         04/06
# 26                                        slim                    01-01-1993
# 27                                     neither                         29/03
# 28                                        slim                    1996-11-06
# 29   I have no idea what you are talking about                         11-08
# ..                                         ...                           ...
# 246                                        fat                 22+1/4.5*2/92
# 247                                    neither                    19/10/1995
# 248                                    neither                    09-06-1989
# 249  I have no idea what you are talking about              4 september 1995
# 250  I have no idea what you are talking about                         10-08
# 251                                    neither                    12-01-1995
# 252                                        fat                          10/5
# 253                                        fat                     july 1994
# 254  I have no idea what you are talking about                             #
# 255                                    neither                         21-09
# 256                                       slim                    17/07/1996
# 257                                        fat                   20.03.1996.
# 258                                        fat                          0704
# 259                                        fat                    27-03-1992
# 260                                    neither                          1994
# 261  I have no idea what you are talking about                    20.02.1996
# 262                                    neither                    14-04-1996
# 263                                    neither                  september 16
# 264                                        fat                         25-03
# 265  I have no idea what you are talking about                    25/07/1994
# 266                                       slim                      1-1-2030
# 267                                        fat                    04/09/1994
# 268                                        fat                    14-04-1993
# 269  I have no idea what you are talking about                         08-04
# 270                                        fat                      09041996
# 271                                       slim              first of october
# 272                                        fat                    21/10/1995
# 273                                        fat                    20-11-1990
# 274                                       slim                     14/7/1998
# 275                                    neither                    25-11-1994
#
#     Number of neighbors sitting around you? Did you stand up?  \
# 0                                         3                no
# 1                                         1                no
# 2                                         0           unknown
# 3                                         2                no
# 4                                         2                no
# 5                                         0               yes
# 6                                      Many                no
# 7                                         0               yes
# 8                                         0                no
# 9                                 Infinite                 no
# 10                                      470                no
# 11                                        3                no
# 12                                        3                no
# 13                                        1                no
# 14                                        2                no
# 15                                       11                no
# 16                                        6                no
# 17                                        7                no
# 18                                        3               yes
# 19                                        1                no
# 20                                        2                no
# 21                                    A lot                no
# 22                                        4                no
# 23                                        1                no
# 24                                        1                no
# 25                                        0                no
# 26                                        5                no
# 27                                        1                no
# 28                                        2                no
# 29                                        2                no
# ..                                      ...               ...
# 246                                       1                no
# 247                                       5                no
# 248                                       2                no
# 249                                       2                no
# 250                                       3                no
# 251                                       0                no
# 252                                       3                no
# 253                                       7                no
# 254                                       5                no
# 255                                       6                no
# 256                                       2                no
# 257                                       2                no
# 258                                       3                no
# 259                                      35                no
# 260                                       6                no
# 261                                       7                no
# 262                                       8                no
# 263                                       3                no
# 264                                       2                no
# 265                                       1                no
# 266                                      77                no
# 267                                      10                no
# 268                                       9                no
# 269                                       5                no
# 270                                     9,3                no
# 271                                four (4)           unknown
# 272                                      80                no
# 273                                       k               yes
# 274                                      50           unknown
# 275                                       5                no
#
#     You can get 100 euros if you win a local DM competition, or we don’t hold any competitions and I give everyone some money (not the same amount!). How much do you think you would deserve then?   \
# 0                                                  100
# 1                                                    0
# 2                                                    0
# 3                                                   42
# 4                                               second
# 5                                               Barkie
# 6                                                  100
# 7                                        Don't so much
# 8                                                    0
# 9                                       Above average
# 10                                                  20
# 11                                                0,25
# 12                                           100000000
# 13                                                 100
# 14                                                  95
# 15                                                  50
# 16                                                  30
# 17                                                  30
# 18                                                  50
# 19                                                 100
# 20                                                 100
# 21                                                 100
# 22                                                   0
# 23                                                  10
# 24                                           Barkie 20
# 25                                                0,01
# 26                                                   5
# 27                                                0,25
# 28                                                 100
# 29                                                  50
# ..                                                 ...
# 246                                                 10
# 247                                                  1
# 248                                                 17
# 249                                                  1
# 250                                                 €1
# 251                                                 99
# 252                                                100
# 253                                                4,7
# 254                                212.765.957.446.809
# 255                                                 20
# 256                                                 77
# 257                                   spare some coins
# 258                                                 40
# 259                                                101
# 260                                                  1
# 261                                                 50
# 262                                                  1
# 263                                                  3
# 264                                                  1
# 265                                                  0
# 266                          some money would be nice
# 267                                                0,5
# 268                                               0,25
# 269                                               0,25
# 270                                                 10
# 271                                                0,1
# 272                                                100
# 273                                   100/no. students
# 274                                                100
# 275                                                100
#
#               Give a random number Time you went to be Yesterday  \
# 0                                6                         23:00
# 1                                7                             3
# 2                                0                             0
# 3                            1,645                           0,3
# 4                               66                            20
# 5                              420                          0000
# 6                              739                         22:00
# 7                                5                          24,3
# 8                               31                         03:30
# 9                                5                         02:00
# 10                            3851                            11
# 11                               6                             3
# 12                               7                          0:40
# 13                              16                          2330
# 14                         314.152                         00:00
# 15                              11                          2:00
# 16                               5                          5 am
# 17                              17                            22
# 18                               7                         24:00
# 19                               7                         23:00
# 20                               2                            21
# 21                               6                         01:03
# 22                             888                         18:00
# 23                               2                         00:00
# 24                      0251656723                       2:30 am
# 25   17572857155648217566617584166                         01:00
# 26                               6                          1 AM
# 27                               9                         23:30
# 28              579659987878648768                         22:30
# 29                               9                         22:00
# ..                             ...                           ...
# 246                     3,14150692                         23:10
# 247                              5                          3:30
# 248                              9                          2 am
# 249                         491995                            12
# 250                              5                          2 am
# 251                              1                         12 pm
# 252                              5                             4
# 253                              5                         01:30
# 254                              7                           1am
# 255                              7                           3,2
# 256                              7                          1:45
# 257                              9    it was actually today, 4am
# 258                              3                         02:00
# 259                        9,99999                         01:30
# 260                              8                         02:00
# 261                              8                  Today at 3am
# 262                              5                            22
# 263                              3                           2am
# 264                              8                      ~1100 pm
# 265                   832795585298                        3:00am
# 266                              7                             0
# 267                              3                          1 AM
# 268                         8,8888                         23:56
# 269                              3                         23:30
# 270                              7                         23:00
# 271                      sqrt (-1)                    10 o clock
# 272                             10                          2:00
# 273                             42                         02:00
# 274                             79                          1:30
# 275                              5                         00:30
#
#                     What makes a good day for you (1)?  \
# 0                                                  sun
# 1                                                   DM
# 2                                                    0
# 3                                              Winning
# 4                                                 kiss
# 5                                                Ganja
# 6                                            chocolate
# 7                                 Stay with my friends
# 8                                Done something useful
# 9                                          A sunny day
# 10                                                 sun
# 11                                                 Sun
# 12                                          Good sleep
# 13                                               Girls
# 14                                                 sun
# 15                                                Work
# 16                                If i went to the gym
# 17                                                 Sun
# 18                                            Sunshine
# 19                                                 Sun
# 20                                              Horses
# 21                                                 Sun
# 22                                           good news
# 23                                            Sunshine
# 24                                                 Sun
# 25                                                 Sea
# 26                                            Sunshine
# 27                                            Sunshine
# 28   Tony chocolonely toffee pretzel donkere melk o...
# 29                                                 Sun
# ..                                                 ...
# 246                                        Zonnige dag
# 247                                           Sunshine
# 248                                   favourite person
# 249                                             Warmth
# 250                                       Good weather
# 251                                            Day off
# 252                                           no class
# 253                                           Sunshine
# 254                                                Sun
# 255                            Sunny day of relaxation
# 256                                         No lecture
# 257                                        good people
# 258                                         not Monday
# 259                   Time for: reading/music/training
# 260                                                Sun
# 261                                               Beer
# 262                                               Goud
# 263                                                Sun
# 264                                         Much sleep
# 265                                        A nice hike
# 266                                          Football
# 267                                        Temperature
# 268                                       Nice company
# 269                              Having friends around
# 270                             Good data mining grade
# 271                                        Good coffee
# 272                                       Arsenal wins
# 273                                   eating chocolate
# 274                                         Chocolate
# 275                                           Sunshine
#
#          What makes a good day for you (2)?  \
# 0                                   lecture
# 1                                        AI
# 2                                         0
# 3                                      Food
# 4                                      love
# 5                                       Sun
# 6                                       Sun
# 7                                       Sun
# 8                                   Had fun
# 9                               Relax walks
# 10                                    sleep
# 11                                     food
# 12                           Good breakfast
# 13                                  Alcohol
# 14                                     food
# 15                               Good sleep
# 16                             Healthy food
# 17                                 Football
# 18                               Good meals
# 19                                Good food
# 20                                Chocolate
# 21                                Nice food
# 22                           very good news
# 23                                Nice food
# 24                                 Relaxing
# 25                                  Weather
# 26                                  Holiday
# 27                                 Vacation
# 28                      Cuddling with dogs
# 29                                   Summer
# ..                                      ...
# 246                                 F1 race
# 247                            Productivity
# 248                              good sleep
# 249                                      .
# 250                             Good grades
# 251                                   Pasta
# 252                            good weather
# 253                                Swimming
# 254                                    Food
# 255                  Eating delicious food
# 256                         Time for sports
# 257                                    wine
# 258                                     yes
# 259                  Being with a loved one
# 260                                    Food
# 261  Petting dog (preferably more than one)
# 262                                   Music
# 263                           Football game
# 264                                 Winning
# 265         A lot of interesting work done
# 266                               Mo Money
# 267                               Free time
# 268                         New experiences
# 269                                Laughing
# 270                                   pizza
# 271                       Italian vineyards
# 272                                  Sports
# 273                           not being fat
# 274                                  Poepen
# 275                                  Coffee
#
#     What is your stress level (0-100)?  Birth Day  Birth Month  Birth Year
# 0                                  NaN        NaN          NaN         NaN
# 1                                    1        9.0          7.0      1992.0
# 2                                  100        4.0          8.0      1995.0
# 3                                    0       29.0          9.0      1993.0
# 4                                  100        2.0         12.0         NaN
# 5                                  100       31.0         12.0      1994.0
# 6                                   80        9.0         10.0      1995.0
# 7                                   50       22.0          7.0      1996.0
# 8                                    0       30.0          2.0      1945.0
# 9                                   80        NaN          NaN         NaN
# 10                                 150       10.0          6.0      1991.0
# 11                                  20        NaN          NaN         NaN
# 12                                  10       18.0          3.0      1994.0
# 13                                  16        2.0          8.0      1996.0
# 14                                  50        1.0          5.0         NaN
# 15                                  10        NaN          NaN      1996.0
# 16                                   0        3.0          3.0      1994.0
# 17                                  17       17.0          5.0      1994.0
# 18                                  40       28.0          8.0         NaN
# 19                                  20       27.0         12.0      1996.0
# 20                                  12       18.0         10.0      1996.0
# 21                                   2       21.0          8.0      1995.0
# 22                                  63       10.0          6.0         NaN
# 23                                   0        9.0          8.0      1996.0
# 24                                   0       24.0          2.0      1994.0
# 25                                  98        4.0          6.0         NaN
# 26                                  20        1.0          1.0      1993.0
# 27                                  10       29.0          3.0         NaN
# 28                                   3       11.0          6.0      1996.0
# 29                                   5       11.0          8.0         NaN
# ..                                 ...        ...          ...         ...
# 246                                 67       22.0          1.0         4.0
# 247                                  5       19.0         10.0      1995.0
# 248                                 55        9.0          6.0      1989.0
# 249                                 90        4.0          9.0      1995.0
# 250                                  5       10.0          8.0         NaN
# 251                                  0       12.0          1.0      1995.0
# 252                                 20       10.0          5.0         NaN
# 253                                  7        NaN          7.0      1994.0
# 254                       100000000000        NaN          NaN         NaN
# 255                                 10       21.0          9.0         NaN
# 256                                 17       17.0          7.0      1996.0
# 257                               10^3       20.0          3.0      1996.0
# 258                                 55        7.0          4.0         NaN
# 259                                 30       27.0          3.0      1992.0
# 260                                 10        NaN          NaN      1994.0
# 261                                100       20.0          2.0      1996.0
# 262                                200       14.0          4.0      1996.0
# 263                                 15       16.0          9.0         NaN
# 264                                 10       25.0          3.0         NaN
# 265                                 15       25.0          7.0      1994.0
# 266                                200        1.0          1.0      2030.0
# 267                                 50        4.0          9.0      1994.0
# 268                                 34       14.0          4.0      1993.0
# 269                                 60        8.0          4.0         NaN
# 270                                 60        9.0          4.0      1996.0
# 271                               99,9        NaN         10.0         NaN
# 272                                  0       21.0         10.0      1995.0
# 273                                 80       20.0         11.0      1990.0
# 274                                 98       14.0          7.0      1998.0
# 275                                 55       25.0         11.0      1994.0
#
# [276 rows x 20 columns]

# %% [markdown]
# ## 2.3 Normalize Neighbors

# %%
def removenonnum(number):
    numlist = []
    for x in number:
        if not x.isdigit():
            if bool(re.match('^(?=.*,.*)',x)):
                numlist.append(x)
            else:
                pass
        else:
            numlist.append(x)
    number = "".join(numlist)
    number = re.sub(' +', ' ', number)
    return number

# %%
for index, row in data_processed.iterrows():
    neighbors = removenonnum(row[9])
    data_processed.iloc[index][9] = neighbors

data_processed[data_processed.columns[9]] = data_processed[data_processed.columns[9]].replace(r'', np.nan, regex=True)

# %% [raw]
# data_neighbors = data_processed.groupby(data_processed.columns[9])

# %% [raw]
# data_neighbors.groups

# %% [markdown]
# ## 2.4 Normalize DM Competition

# %%
for index, row in data_processed.iterrows():
    competition = removenonnum(row[11])
    data_processed.iloc[index][11] = competition

data_processed[data_processed.columns[9]] = data_processed[data_processed.columns[9]].replace(r'', np.nan, regex=True)

# %% [raw]
# data_competition = data_processed.groupby(data_processed.columns[11])

# %% [raw]
# data_competition.groups

# %% [markdown]
# # 3. Save Pre-Processed Data

# %%
data_processed.to_csv('ODI-2019-processed.csv', header=True, index=False)
