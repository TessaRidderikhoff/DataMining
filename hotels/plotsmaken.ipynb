# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn import tree
import random
import math
from datetime import timedelta
from scipy import stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# RandomForestData = [['10 trees', 0.25064], ['100 trees', 0.30515] ['300 trees', 0.31630]]

data = [['10', 0.25064], ['100', 0.30515], ['300', 0.31630]]
RFdf = pd.DataFrame(data, columns = ['Number of decision trees', 'Kaggle score'])

plot = sns.barplot(x = 'Number of decision trees', y = 'Kaggle score', data = RFdf)
plot.set(ylim = (0, 0.5))
# Out:
# [(0, 0.5)]

# %%
data = [['Full dataset', '100', 0.29784], ['Downsampled', '100', 0.30515], ['Full dataset', '10', 0.24108], ['Downsampled', '10', 0.25064]]
datadf = pd.DataFrame(data, columns = ['Dataset' ,'Number of decision trees', 'Kaggle score'])

plot2 = sns.barplot(x = 'Number of decision trees', y = 'Kaggle score', hue = 'Dataset', data = datadf)
plot2.set(ylim = (0, 0.5))
# Out:
# [(0, 0.5)]

# %%
data = [['Price excluded','10', 0.24582], ['Price excluded', '100', 0.29356], ['Price included', '10', 0.25059], 
        ['Price included', '100', 0.30177]]
RFdf = pd.DataFrame(data, columns = ['Price', 'Number of decision trees', 'Kaggle score'])

plot = sns.barplot(x = 'Number of decision trees', y = 'Kaggle score', hue = 'Price', data = RFdf)
plot.set(ylim = (0, 0.5))
# Out:
# [(0, 0.5)]

# %%
lmdata = [[20, 0.29526], [100, 0.32198], [250, 0.33382]]
lmdf = pd.DataFrame(lmdata, columns = ['Number of estimators', 'Kaggle score'])

plot = sns.barplot(x = 'Number of estimators', y = 'Kaggle score', data = lmdf)
plot.set(ylim = (0, 1))
# Out:
# [(0, 1)]

# %%
alldata = [['LM', 20, 0.29526], ['LM', 100, 0.32198], ['LM', 250, 0.33382], ['RF',10, 0.25064], 
           ['RF', 100, 0.30515], ['RF', 300, 0.31630]]
alldf = pd.DataFrame(alldata, columns = ['Algorithm', 'Number of estimators', 'Kaggle score'])

plot = sns.lineplot(x = 'Number of estimators', y = 'Kaggle score', hue = 'Algorithm', data = alldf)

# %%
clickdata = [['Booked', 0.24289], ['Clicked and booked', 0.25064]]
clickdf = pd.DataFrame(clickdata, columns = ['Predictor', 'Kaggle score'])

plot = sns.barplot(x = 'Predictor', y = 'Kaggle score', data = clickdf)
plot.set(ylim = (0, 0.3))
# Out:
# [(0, 0.3)]

# %%
10 downsampled = 0.5505959988639542
100 downsampled = 0.582841279156974
10 full = 0.9547915867828353
