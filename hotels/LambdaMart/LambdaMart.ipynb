# %%
import pyltr

# %%
with open('train.txt') as trainfile, \
        open('test.txt') as evalfile:
    TX, Ty, Tqids, _ = pyltr.data.letor.read_dataset(trainfile)
    EX, Ey, Eqids, _ = pyltr.data.letor.read_dataset(evalfile)

# %%
metric = pyltr.metrics.NDCG(k=10)

# %%
model = pyltr.models.LambdaMART(
    metric=metric,
    n_estimators=1000,
    learning_rate=0.02,
    max_features=0.5,
    query_subsample=0.5,
    max_leaf_nodes=10,
    min_samples_leaf=64,
    verbose=1,
)

# %%
model.fit(TX, Ty, Tqids)
# Out:
#  Iter  Train score  OOB Improve    Remaining                           Monitor Output
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-33-cbaf92ba8970> in <module>
# ----> 1 model.fit(TX, Ty, Tqids)
#
# ~/anaconda3/lib/python3.7/site-packages/pyltr/models/lambdamart.py in fit(self, X, y, qids, monitor)
#     198
#     199         n_stages = self._fit_stages(X, y, qids, y_pred,
# --> 200                                     random_state, begin_at_stage, monitor)
#     201
#     202         if n_stages < self.estimators_.shape[0]:
#
# ~/anaconda3/lib/python3.7/site-packages/pyltr/models/lambdamart.py in _fit_stages(self, X, y, qids, y_pred, random_state, begin_at_stage, monitor)
#     401                 for qid, a, b, _ in query_groups[~query_mask]:
#     402                     old_oob_total_score += self.metric.evaluate_preds(
# --> 403                         qid, y[a:b], y_pred[a:b])
#     404
#     405             y_pred = self._fit_stage(i, X, y, qids, y_pred, sample_weight,
#
# ~/anaconda3/lib/python3.7/site-packages/pyltr/metrics/_metrics.py in evaluate_preds(self, qid, targets, preds)
#     103
#     104         """
# --> 105         return self.evaluate(qid, get_sorted_y(targets, preds))
#     106
#     107     def calc_random_ev(self, qid, targets):
#
# ~/anaconda3/lib/python3.7/site-packages/pyltr/metrics/dcg.py in evaluate(self, qid, targets)
#      71
#      72     def evaluate(self, qid, targets):
# ---> 73         return (self._dcg.evaluate(qid, targets) /
#      74                 max(_EPS, self._get_ideal(qid, targets)))
#      75
#
# ~/anaconda3/lib/python3.7/site-packages/pyltr/metrics/dcg.py in evaluate(self, qid, targets)
#      24     def evaluate(self, qid, targets):
#      25         return sum(self._gain_fn(t) * self._get_discount(i)
# ---> 26                    for i, t in enumerate(targets) if i < self.k)
#      27
#      28     def calc_swap_deltas(self, qid, targets, coeff=1.0):
#
# ~/anaconda3/lib/python3.7/site-packages/pyltr/metrics/dcg.py in <genexpr>(.0)
#      24     def evaluate(self, qid, targets):
#      25         return sum(self._gain_fn(t) * self._get_discount(i)
# ---> 26                    for i, t in enumerate(targets) if i < self.k)
#      27
#      28     def calc_swap_deltas(self, qid, targets, coeff=1.0):
#
# ~/anaconda3/lib/python3.7/site-packages/pyltr/metrics/gains.py in _exp2_gain(x)
#      16
#      17 def _exp2_gain(x):
# ---> 18     return math.exp(x * _LOG2) - 1.0
#      19
#      20
#
# OverflowError: math range error
